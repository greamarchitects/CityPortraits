# %% [markdown]
# # Model
#
# Prototype of the City Portrait model including its three blocks: Analysis, Mapping, and Projection.

# %%
from IPython.display import HTML

HTML("""
<div class="mcp-dashboard">

  <!-- =============================
       BLOCK 1: ANALYSIS
       Components + Feature
       ============================= -->
  <section class="mcp-block">
    <header class="mcp-block-header">
      <span class="mcp-kicker">Block 1</span>
      <h2>Analysis</h2>
      <p> Analytical components of the model.</p>
    </header>

    <div class="mcp-grid mcp-grid-3">
      <article class="mcp-card">
        <h3>Component: Point</h3>
        <p>Point-based spatial observations, landmarks, buildings, events, or sampled locations.</p>
        <div id="mcp-point" class="mcp-map mcp-map-small"></div>
      </article>

      <article class="mcp-card">
        <h3>Component: Axial</h3>
        <p>Axial structures such as streets, routes, visual axes, movement lines, or connectivity paths.</p>
        <div id="mcp-axial" class="mcp-map mcp-map-small"></div>
      </article>

      <article class="mcp-card">
        <h3>Component: Patch</h3>
        <p>Patch-based spatial units such as building blocks, parcels, land-use areas, or morphological zones.</p>
        <div id="mcp-patch" class="mcp-map mcp-map-small"></div>
      </article>
    </div>

    <div class="mcp-grid mcp-grid-feature">
      <article class="mcp-card">
        <h3>Feature</h3>
        <div id="mcp-feature" class="mcp-map mcp-map-medium"></div>
      </article>

      <article class="mcp-card mcp-text-card">
        <h3>Feature Description</h3>
        <p>Portraied main features relates to Point, Axial, and Patch components.</p>
      </article>
    </div>
  </section>

  <!-- =============================
       BLOCK 2: MAPPING
       Full-width map output
       ============================= -->
  <section class="mcp-block">
    <header class="mcp-block-header">
      <span class="mcp-kicker">Block 2</span>
      <h2>Mapping</h2>
      <p> Spatial Analysis Results.</p>
    </header>

    <article class="mcp-card">
      <h3>Map</h3>
      <div id="mcp-main-map" class="mcp-map mcp-map-large"></div>
    </article>
  </section>

  <!-- =============================
       BLOCK 3: PROJECTION
       Graph + Artifacts
       ============================= -->
  <section class="mcp-block">
    <header class="mcp-block-header">
      <span class="mcp-kicker">Block 3</span>
      <h2>Projection</h2>
      <p>Relational projection, graph output, and generated artifacts.</p>
    </header>

    <div class="mcp-grid mcp-grid-graph">
  <article class="mcp-card mcp-text-card">
    <h3>Graph</h3>
    <p>Graph portraing the relationships between components, artifacts, places, actors, and events.</p>
  </article>

  <article class="mcp-card mcp-graph-card">
    <h3>Graph</h3>

    <div class="mcp-graph-toolbar">
      <button id="graph-reset-btn" type="button">Reset graph</button>
    </div>

    <div id="cy-network" class="mcp-graph-box"></div>
  </article>
</div>

    <div class="mcp-grid mcp-grid-3">
      <article class="mcp-card">
        <h3>Artifact: Portrait</h3>
        <p>Descriptive spatial portrait.</p>
        <div id="mcp-portrait" class="mcp-map mcp-map-small"></div>
      </article>

      <article class="mcp-card">
        <h3>Artifact: Pattern</h3>
        <p>Recurring spatial, historical, or morphological patterns.</p>
        <div id="mcp-pattern" class="mcp-map mcp-map-small"></div>
      </article>

      <article class="mcp-card">
        <h3>Artifact: Projection</h3>
        <p>Projected scenarios, previews, or future model outputs.</p>
        <div id="mcp-project" class="mcp-map mcp-map-small"></div>
      </article>
    </div>
  </section>

</div>
""")
# Out:
# <div class="mcp-dashboard">
#
#   <!-- =============================
#        BLOCK 1: ANALYSIS
#        Components + Feature
#        ============================= -->
#   <section class="mcp-block">
#     <header class="mcp-block-header">
#       <span class="mcp-kicker">Block 1</span>
#       <h2>Analysis</h2>
#       <p> Analytical components of the model.</p>
#     </header>
#
#     <div class="mcp-grid mcp-grid-3">
#       <article class="mcp-card">
#         <h3>Component: Point</h3>
#         <p>Point-based spatial observations, landmarks, buildings, events, or sampled locations.</p>
#         <div id="mcp-point" class="mcp-map mcp-map-small"></div>
#       </article>
#
#       <article class="mcp-card">
#         <h3>Component: Axial</h3>
#         <p>Axial structures such as streets, routes, visual axes, movement lines, or connectivity paths.</p>
#         <div id="mcp-axial" class="mcp-map mcp-map-small"></div>
#       </article>
#
#       <article class="mcp-card">
# ...
